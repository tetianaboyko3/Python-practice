# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('health_insurance_cross_sell_prediction.csv')

# %%
# Подивимося тип дата фрейму
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Подивимося розмір дата фрейму
df_shape=df.shape
df_shape
# Out:
# (381109, 12)

# %% [markdown]
# Тобто розмір файлу:
# 381109 рядочків, 12 колонок

# %%
# дізнатися кількість рядочків
df.shape[0]
# Out:
# 381109

# %%
# дізнатися кількість колонок
df.shape[1]
# Out:
# 12

# %%
len(df)
# Out:
# 381109

# %%
#Подивитися розмір колонок(в бітах)
df.memory_usage()
# Out:
# Index                       132
# id                      3048872
# Gender                  3048872
# Age                     3048872
# Driving_License         3048872
# Region_Code             3048872
# Previously_Insured      3048872
# Vehicle_Age             3048872
# Vehicle_Damage          3048872
# Annual_Premium          3048872
# Policy_Sales_Channel    3048872
# Vintage                 3048872
# Response                3048872
# dtype: int64

# %%
# Просумувати розмір колонок
df.memory_usage().sum()
# Out:
# np.int64(36586596)

# %%
# Перевести з бітів в мегабайти
total_bytes = df.memory_usage().sum()
total_megabytes = total_bytes/(1024*1024)
total_megabytes
# Out:
# np.float64(34.89169692993164)

# %%
# Зчитати частину даних(100 рядків)
pd.read_csv('health_insurance_cross_sell_prediction.csv', nrows = 100)
# Out:
#      id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0     1    Male   44                1         28.0                   0
# 1     2    Male   76                1          3.0                   0
# 2     3    Male   47                1         28.0                   0
# 3     4    Male   21                1         11.0                   1
# 4     5  Female   29                1         41.0                   1
# ..  ...     ...  ...              ...          ...                 ...
# 95   96  Female   23                1         30.0                   0
# 96   97    Male   50                1         28.0                   0
# 97   98  Female   62                1         28.0                   0
# 98   99  Female   21                1          2.0                   0
# 99  100  Female   24                1          7.0                   1
#
#    Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# ...

# %%
# перші 10 записів
df.head(10)
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
# 5   6  Female   24                1         33.0                   0
# 6   7    Male   23                1         11.0                   0
# 7   8  Female   56                1         28.0                   0
# 8   9  Female   24                1          3.0                   1
# 9  10  Female   32                1          6.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# ...

# %%
# Останні 5 записів
df.tail(5)
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 381104  381105    Male   74                1         26.0                   1
# 381105  381106    Male   30                1         37.0                   1
# 381106  381107    Male   21                1         30.0                   1
# 381107  381108  Female   68                1         14.0                   0
# 381108  381109    Male   46                1         29.0                   0
#
#        Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 381104    1-2 Year             No         30170.0                  26.0
# 381105    < 1 Year             No         40016.0                 152.0
# 381106    < 1 Year             No         35118.0                 160.0
# 381107   > 2 Years            Yes         44617.0                 124.0
# 381108    1-2 Year             No         41777.0                  26.0
#
#         Vintage  Response
# 381104       88         0
# ...

# %%
# Покажи від 100-го до 110 рядочка з кроком 2
df[100:110:2]
# Out:
#       id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 100  101    Male   52                1         28.0                   1
# 102  103  Female   20                1         30.0                   0
# 104  105    Male   29                1         41.0                   1
# 106  107  Female   23                1         41.0                   1
# 108  109    Male   72                1         46.0                   1
#
#     Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 100    1-2 Year             No         36033.0                  26.0       92
# 102    < 1 Year            Yes         33227.0                 160.0       78
# 104    < 1 Year            Yes         43046.0                 163.0      222
# 106    < 1 Year             No         36674.0                 152.0      158
# 108    1-2 Year            Yes         28698.0                  30.0      216
#
#      Response
# 100         0
# 102         0
# 104         0
# ...

# %%
df.loc[200]
# Out:
# id                           201
# Gender                      Male
# Age                           55
# Driving_License                1
# Region_Code                 28.0
# Previously_Insured             0
# Vehicle_Age             1-2 Year
# Vehicle_Damage               Yes
# Annual_Premium           49470.0
# Policy_Sales_Channel       124.0
# Vintage                      203
# Response                       0
# Name: 200, dtype: object

# %%
df[200] # помилка. в дужках очікується назва колонки
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 200
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df[200]
#
# ...

# %%
df[:5] # виведе до 5 рядка включно
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
df[5:] #виведе все починаючи з 5 рядка
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 5            6  Female   24                1         33.0                   0
# 6            7    Male   23                1         11.0                   0
# 7            8  Female   56                1         28.0                   0
# 8            9  Female   24                1          3.0                   1
# 9           10  Female   32                1          6.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 381104  381105    Male   74                1         26.0                   1
# 381105  381106    Male   30                1         37.0                   1
# 381106  381107    Male   21                1         30.0                   1
# 381107  381108  Female   68                1         14.0                   0
# 381108  381109    Male   46                1         29.0                   0
#
# ...

# %%
df.loc[100]
# Out:
# id                           101
# Gender                      Male
# Age                           52
# Driving_License                1
# Region_Code                 28.0
# Previously_Insured             1
# Vehicle_Age             1-2 Year
# Vehicle_Damage                No
# Annual_Premium           36033.0
# Policy_Sales_Channel        26.0
# Vintage                       92
# Response                       0
# Name: 100, dtype: object

# %%
type(df.loc[100])
# Out:
# pandas.core.series.Series

# %%
df.loc[100:101]
# Out:
#       id Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 100  101   Male   52                1         28.0                   1
# 101  102   Male   24                1          3.0                   1
#
#     Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 100    1-2 Year             No         36033.0                  26.0       92
# 101    < 1 Year             No         28139.0                 152.0       52
#
#      Response
# 100         0
# 101         0

# %%
# Зробити з Series формат Data Frame
pd.DataFrame(df.loc[300])
# Out:
#                            300
# id                         301
# Gender                    Male
# Age                         21
# Driving_License              1
# Region_Code               29.0
# Previously_Insured           1
# Vehicle_Age           < 1 Year
# Vehicle_Damage              No
# Annual_Premium         43798.0
# Policy_Sales_Channel     152.0
# Vintage                    258
# Response                     0

# %%
pd.DataFrame(df.loc[300]).T   # хочу розвернути(транспонувати) за допомогою " .Т "
# Out:
#       id Gender Age Driving_License Region_Code Previously_Insured  \
# 300  301   Male  21               1        29.0                  1
#
#     Vehicle_Age Vehicle_Damage Annual_Premium Policy_Sales_Channel Vintage  \
# 300    < 1 Year             No        43798.0                152.0     258
#
#     Response
# 300        0

# %%
df[100:110:2].iloc[0]
# Out:
# id                           101
# Gender                      Male
# Age                           52
# Driving_License                1
# Region_Code                 28.0
# Previously_Insured             1
# Vehicle_Age             1-2 Year
# Vehicle_Damage                No
# Annual_Premium           36033.0
# Policy_Sales_Channel        26.0
# Vintage                       92
# Response                       0
# Name: 100, dtype: object

# %%
# буде помилка
df[100:110:2].iloc[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 2
#       1 # буде помилка
# ----> 2 df[100:110:2].iloc[100]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# ...

# %%
df[499:550:3].iloc[0]
# Out:
# id                           500
# Gender                      Male
# Age                           20
# Driving_License                1
# Region_Code                 36.0
# Previously_Insured             1
# Vehicle_Age             < 1 Year
# Vehicle_Damage                No
# Annual_Premium           27397.0
# Policy_Sales_Channel       152.0
# Vintage                       13
# Response                       0
# Name: 499, dtype: object

# %%
df.dtypes
# Out:
# id                        int64
# Gender                   object
# Age                       int64
# Driving_License           int64
# Region_Code             float64
# Previously_Insured        int64
# Vehicle_Age              object
# Vehicle_Damage           object
# Annual_Premium          float64
# Policy_Sales_Channel    float64
# Vintage                   int64
# Response                  int64
# dtype: object

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'Response'],
#       dtype='object')

# %%
df.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  381109.000000  381109.000000    381109.000000  381109.000000
# mean   190555.000000      38.822584         0.997869      26.388807
# std    110016.836208      15.511611         0.046110      13.229888
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95278.000000      25.000000         1.000000      15.000000
# 50%    190555.000000      36.000000         1.000000      28.000000
# 75%    285832.000000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel  \
# count       381109.000000   381109.000000         381109.000000
# mean             0.458210    30564.389581            112.034295
# std              0.498251    17213.155057             54.203995
# min              0.000000     2630.000000              1.000000
# ...

# %%
with pd.option_context("display.precision", 2):
    display(df.describe())
# Out:
#               id        Age  Driving_License  Region_Code  Previously_Insured  \
# count  381109.00  381109.00        381109.00    381109.00           381109.00
# mean   190555.00      38.82             1.00        26.39                0.46
# std    110016.84      15.51             0.05        13.23                0.50
# min         1.00      20.00             0.00         0.00                0.00
# 25%     95278.00      25.00             1.00        15.00                0.00
# 50%    190555.00      36.00             1.00        28.00                0.00
# 75%    285832.00      49.00             1.00        35.00                1.00
# max    381109.00      85.00             1.00        52.00                1.00
#
#        Annual_Premium  Policy_Sales_Channel    Vintage   Response
# count       381109.00             381109.00  381109.00  381109.00
# mean         30564.39                112.03     154.35       0.12
# std          17213.16                 54.20      83.67       0.33
# ...

# %%
with pd.option_context("display.precision", 2):
    display(df.describe(percentiles=[0.01, 0.1, 0.2, 0.5, 0.7, 0.9, 0.99]))
# Out:
#               id        Age  Driving_License  Region_Code  Previously_Insured  \
# count  381109.00  381109.00        381109.00    381109.00           381109.00
# mean   190555.00      38.82             1.00        26.39                0.46
# std    110016.84      15.51             0.05        13.23                0.50
# min         1.00      20.00             0.00         0.00                0.00
# 1%       3812.08      20.00             1.00         2.00                0.00
# 10%     38111.80      22.00             1.00         8.00                0.00
# 20%     76222.60      24.00             1.00        11.00                0.00
# 50%    190555.00      36.00             1.00        28.00                0.00
# 70%    266776.60      47.00             1.00        31.00                1.00
# 90%    342998.20      62.00             1.00        46.00                1.00
# 99%    377297.92      77.00             1.00        50.00                1.00
# ...

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'Response'],
#       dtype='object')

# %%
df['id']
# Out:
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
#            ...
# 381104    381105
# 381105    381106
# 381106    381107
# 381107    381108
# 381108    381109
# Name: id, Length: 381109, dtype: int64

# %%
df['Gender']
# Out:
# 0           Male
# 1           Male
# 2           Male
# 3           Male
# 4         Female
#            ...
# 381104      Male
# 381105      Male
# 381106      Male
# 381107    Female
# 381108      Male
# Name: Gender, Length: 381109, dtype: object

# %%
# колонки ще можна вибрати ось так
df.id
# Out:
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
#            ...
# 381104    381105
# 381105    381106
# 381106    381107
# 381107    381108
# 381108    381109
# Name: id, Length: 381109, dtype: int64

# %%
df.Gender
# Out:
# 0           Male
# 1           Male
# 2           Male
# 3           Male
# 4         Female
#            ...
# 381104      Male
# 381105      Male
# 381106      Male
# 381107    Female
# 381108      Male
# Name: Gender, Length: 381109, dtype: object

# %%
df['Нова колонка'] = 1

# %%
df['Нова колонка']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 381104    1
# 381105    1
# 381106    1
# 381107    1
# 381108    1
# Name: Нова колонка, Length: 381109, dtype: int64

# %%
# не спрацює
df.Нова колонка
# Out:
#   Cell In[43], line 2
#     df.Нова колонка
#             ^
# SyntaxError: invalid syntax

# %%
# Щоб вибрати кілька колонок
df[['Region_Code','Gender']]
# Out:
#         Region_Code  Gender
# 0              28.0    Male
# 1               3.0    Male
# 2              28.0    Male
# 3              11.0    Male
# 4              41.0  Female
# ...             ...     ...
# 381104         26.0    Male
# 381105         37.0    Male
# 381106         30.0    Male
# 381107         14.0  Female
# 381108         29.0    Male
#
# [381109 rows x 2 columns]

# %%
# створимо новий набір даних і запишемо його в змінну
df_selected_cols = df [['Region_Code', 'Gender', 'Age']]

# %%
df_selected_cols
# Out:
#         Region_Code  Gender  Age
# 0              28.0    Male   44
# 1               3.0    Male   76
# 2              28.0    Male   47
# 3              11.0    Male   21
# 4              41.0  Female   29
# ...             ...     ...  ...
# 381104         26.0    Male   74
# 381105         37.0    Male   30
# 381106         30.0    Male   21
# 381107         14.0  Female   68
# 381108         29.0    Male   46
#
# [381109 rows x 3 columns]

# %%
df_selected_cols[1000:1100]['Gender'][0:10]
# Out:
# 1000      Male
# 1001    Female
# 1002    Female
# 1003    Female
# 1004      Male
# 1005    Female
# 1006      Male
# 1007      Male
# 1008    Female
# 1009    Female
# Name: Gender, dtype: object

# %%
df_selected_cols[1000:1100]['Gender'][0:10].sum() # це просто конкатенація
# Out:
# 'MaleFemaleFemaleFemaleMaleFemaleMaleMaleFemaleFemale'

# %%
df_selected_cols[1000:1100]['Age'][0:10].sum()
# Out:
# np.int64(371)

# %%
df_selected_cols[1000:1100]['Age'][0:10].mean()
# Out:
# np.float64(37.1)

# %%
df_selected_cols[1000:1100]['Age'][0:10][0:5:2].astype(str)
# Out:
# 1000    49
# 1002    26
# 1004    49
# Name: Age, dtype: object

# %%
# Перегляд значень в категоріальних колонках

# %%
df.select_dtypes('object')
# Out:
#         Gender Vehicle_Age Vehicle_Damage
# 0         Male   > 2 Years            Yes
# 1         Male    1-2 Year             No
# 2         Male   > 2 Years            Yes
# 3         Male    < 1 Year             No
# 4       Female    < 1 Year             No
# ...        ...         ...            ...
# 381104    Male    1-2 Year             No
# 381105    Male    < 1 Year             No
# 381106    Male    < 1 Year             No
# 381107  Female   > 2 Years            Yes
# 381108    Male    1-2 Year             No
#
# [381109 rows x 3 columns]

# %%
df.select_dtypes('number') # вибирає колонки, які мають числовий тип
# Out:
#             id  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            1   44                1         28.0                   0
# 1            2   76                1          3.0                   0
# 2            3   47                1         28.0                   0
# 3            4   21                1         11.0                   1
# 4            5   29                1         41.0                   1
# ...        ...  ...              ...          ...                 ...
# 381104  381105   74                1         26.0                   1
# 381105  381106   30                1         37.0                   1
# 381106  381107   21                1         30.0                   1
# 381107  381108   68                1         14.0                   0
# 381108  381109   46                1         29.0                   0
#
#         Annual_Premium  Policy_Sales_Channel  Vintage  Response  Нова колонка
# ...

# %%
df.select_dtypes('object').columns  # наші категоріальні колонки
# Out:
# Index(['Gender', 'Vehicle_Age', 'Vehicle_Damage'], dtype='object')

# %%
df.Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df.Gender.nunique()
# Out:
# 2

# %%
df.Vehicle_Age.unique()
# Out:
# array(['> 2 Years', '1-2 Year', '< 1 Year'], dtype=object)

# %%
df.Vehicle_Age.nunique()
# Out:
# 3

# %%
df.Vehicle_Age.value_counts()
# Out:
# Vehicle_Age
# 1-2 Year     200316
# < 1 Year     164786
# > 2 Years     16007
# Name: count, dtype: int64

# %%
df.Vehicle_Age.value_counts()[['< 1 Year', '> 2 Years']]
# Out:
# Vehicle_Age
# < 1 Year     164786
# > 2 Years     16007
# Name: count, dtype: int64

# %%
df.Vehicle_Age.value_counts()[['< 1 Year', '> 2 Years']].sum()
# Out:
# np.int64(180793)

# %%
gender_counts = df.Gender.value_counts()

# %%
gender_counts
# Out:
# Gender
# Male      206089
# Female    175020
# Name: count, dtype: int64

# %%
gender_counts/gender_counts.sum()  # відсоток по статях
# Out:
# Gender
# Male      0.540761
# Female    0.459239
# Name: count, dtype: float64

# %%
df.Gender.value_counts(normalize=True)
# Out:
# Gender
# Male      0.540761
# Female    0.459239
# Name: proportion, dtype: float64

# %%
example = pd.Series(range(100))

# %%
example
# Out:
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
#       ..
# 95    95
# 96    96
# 97    97
# 98    98
# 99    99
# Length: 100, dtype: int64

# %%
example+3
# Out:
# 0       3
# 1       4
# 2       5
# 3       6
# 4       7
#      ...
# 95     98
# 96     99
# 97    100
# 98    101
# 99    102
# Length: 100, dtype: int64

# %%
list_example = list(range(3))

# %%
list_example+3 # не спрацює
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 list_example+3
#
# TypeError: can only concatenate list (not "int") to list

# %%
list_example*3
# Out:
# [0, 1, 2, 0, 1, 2, 0, 1, 2]
