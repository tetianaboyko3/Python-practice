# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('health_insurance_cross_sell_prediction.csv')

# %%
df[df.Gender=='Male'].Age.describe()
# Out:
# count    206089.000000
# mean         40.903095
# std          15.449718
# min          20.000000
# 25%          26.000000
# 50%          41.000000
# 75%          52.000000
# max          85.000000
# Name: Age, dtype: float64

# %%
df[df.Gender=='Female'].Age.describe()
# Out:
# count    175020.000000
# mean         36.372746
# std          15.223969
# min          20.000000
# 25%          24.000000
# 50%          30.000000
# 75%          46.000000
# max          85.000000
# Name: Age, dtype: float64

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'Response'],
#       dtype='object')

# %%
filter_1 = (df.Gender=='Male') & (df.Age >= 26) & (df.Age <=52)
df[filter_1].Response.value_counts(normalize=True)
# Out:
# Response
# 0    0.815225
# 1    0.184775
# Name: proportion, dtype: float64

# %%
filter_2= (df.Gender=='Male') & ((df.Age < 26) | (df.Age > 52))
df[filter_2].Response.value_counts(normalize=True)
# Out:
# Response
# 0    0.911723
# 1    0.088277
# Name: proportion, dtype: float64

# %%
df.query('Gender == "Male" & Age >= 26 & Age <= 52').Response.value_counts(normalize=True)
# Out:
# Response
# 0    0.815225
# 1    0.184775
# Name: proportion, dtype: float64

# %%
df.query('Gender == "Male" & ((Age < 26) | (Age > 52))').Response.value_counts(normalize=True)
# Out:
# Response
# 0    0.911723
# 1    0.088277
# Name: proportion, dtype: float64

# %%
df.sort_values(by="Age").head()
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 67915    67916    Male   20                1         24.0                   0
# 6316      6317    Male   20                1         27.0                   1
# 193265  193266  Female   20                1         42.0                   0
# 374102  374103    Male   20                1          8.0                   1
# 6332      6333    Male   20                1         17.0                   0
#
#        Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 67915     < 1 Year            Yes         27448.0                 160.0
# 6316      < 1 Year             No          2630.0                 160.0
# 193265    < 1 Year            Yes          2630.0                 160.0
# 374102    < 1 Year             No         35073.0                 160.0
# 6332      < 1 Year            Yes         30618.0                 160.0
#
#         Vintage  Response
# 67915       259         0
# ...

# %%
df.sort_values(by="Age", ascending=False).head() # сортуємо за спаданням колонки Age
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 48875    48876  Female   85                1         45.0                   1
# 213099  213100  Female   85                1         28.0                   0
# 150129  150130    Male   85                1         48.0                   0
# 210249  210250  Female   85                1         28.0                   1
# 137703  137704  Female   85                1         28.0                   0
#
#        Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 48875     1-2 Year             No          2630.0                  26.0
# 213099    1-2 Year            Yes          2630.0                  26.0
# 150129    1-2 Year            Yes          2630.0                 124.0
# 210249    1-2 Year             No         42530.0                  26.0
# 137703    1-2 Year            Yes         51045.0                 124.0
#
#         Vintage  Response
# 48875       102         0
# ...

# %%
df.sort_values(by="Age", ascending=False)[:20]  # виведе 20 записів відсортованих по колонці Вік за спаданням
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 48875    48876  Female   85                1         45.0                   1
# 213099  213100  Female   85                1         28.0                   0
# 150129  150130    Male   85                1         48.0                   0
# 210249  210250  Female   85                1         28.0                   1
# 137703  137704  Female   85                1         28.0                   0
# 100683  100684  Female   85                1         28.0                   0
# 321081  321082  Female   85                1          8.0                   1
# 181135  181136    Male   85                1         28.0                   0
# 109851  109852  Female   85                1         50.0                   0
# 208264  208265  Female   85                1          8.0                   0
# 229103  229104  Female   85                0         28.0                   1
# ...

# %%
# відсортуй за колонками Age за зростанням та Annual_Premium за спаданням і виведи перші 5 записів
df.sort_values(by=["Age", "Annual_Premium"], ascending=[True, False]).head()
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 71046    71047  Female   20                1         47.0                   0
# 165841  165842  Female   20                1         28.0                   1
# 199087  199088    Male   20                1         13.0                   0
# 58455    58456  Female   20                1         36.0                   0
# 275348  275349  Female   20                1         28.0                   0
#
#        Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 71046     < 1 Year             No        152866.0                 160.0
# 165841    < 1 Year             No        117057.0                 160.0
# 199087    < 1 Year            Yes        100227.0                 160.0
# 58455     < 1 Year            Yes         99950.0                 160.0
# 275348    1-2 Year            Yes         99021.0                  26.0
#
#         Vintage  Response
# 71046       285         0
# ...

# %%
# відсортуй за колонками Age за спаданням та Previously_Insured за спаданням і виведи 3 перші записи

df.sort_values(by=["Age", "Previously_Insured"], ascending=[False, False]).head(3)
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 48875    48876  Female   85                1         45.0                   1
# 210249  210250  Female   85                1         28.0                   1
# 229103  229104  Female   85                0         28.0                   1
#
#        Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 48875     1-2 Year             No          2630.0                  26.0
# 210249    1-2 Year             No         42530.0                  26.0
# 229103    1-2 Year             No         27057.0                  26.0
#
#         Vintage  Response
# 48875       102         0
# 210249       64         0
# 229103       65         0

# %%
df.sort_index(axis=1).head() # назви колонок таблиці відсортовано в алфавітному порядку
# Out:
#    Age  Annual_Premium  Driving_License  Gender  Policy_Sales_Channel  \
# 0   44         40454.0                1    Male                  26.0
# 1   76         33536.0                1    Male                  26.0
# 2   47         38294.0                1    Male                  26.0
# 3   21         28619.0                1    Male                 152.0
# 4   29         27496.0                1  Female                 152.0
#
#    Previously_Insured  Region_Code  Response Vehicle_Age Vehicle_Damage  \
# 0                   0         28.0         1   > 2 Years            Yes
# 1                   0          3.0         0    1-2 Year             No
# 2                   0         28.0         1   > 2 Years            Yes
# 3                   1         11.0         0    < 1 Year             No
# 4                   1         41.0         0    < 1 Year             No
#
#    Vintage  id
# 0      217   1
# 1      183   2
# 2       27   3
# 3      203   4
# 4       39   5

# %%
# створення нової колонки
df["New_col"]=3/10
df["New_col"]
# Out:
# 0         0.3
# 1         0.3
# 2         0.3
# 3         0.3
# 4         0.3
#          ...
# 381104    0.3
# 381105    0.3
# 381106    0.3
# 381107    0.3
# 381108    0.3
# Name: New_col, Length: 381109, dtype: float64

# %%
import random
values = [random.choice([1,2,3]) for _ in range(len(df))]

# %%
df['random_category']= values

# %%
df['new_cat']=df.random_category+1

# %%
df[['new_cat','random_category']]
# Out:
#         new_cat  random_category
# 0             4                3
# 1             3                2
# 2             2                1
# 3             2                1
# 4             4                3
# ...         ...              ...
# 381104        3                2
# 381105        3                2
# 381106        3                2
# 381107        3                2
# 381108        4                3
#
# [381109 rows x 2 columns]

# %%
df['new_cat']=df.random_category.apply(lambda x: 'Small' if x<1 else 'Big')

# %%
df[['random_category', 'new_cat']].head()
# Out:
#    random_category new_cat
# 0                3     Big
# 1                2     Big
# 2                1     Big
# 3                1     Big
# 4                3     Big

# %%
add_ten = lambda x,y: x+y+10
print(add_ten(5,2))
# Out:
# 17

# %%
my_lambda = lambda x: 'Small' if x<1 else 'Big'
my_lambda(5)
# Out:
# 'Big'

# %%
my_lambda = lambda x: 'Small' if x<1 else 'Big'
my_lambda(0)
# Out:
# 'Small'

# %%
numbers = [1,2,3,4,5]
squared = map(lambda x: x**2, numbers)
print(list(squared))
# Out:
# [1, 4, 9, 16, 25]

# %%
def category_mapping(val):
    if val== 1:
        return 'Small'
    elif val== 2:
        return 'Medium'
    else:
        return 'Large'

# %%
df['new_cat']= df.random_category.apply(lambda x: category_mapping(x))
df[['random_category', 'new_cat']].head()
# Out:
#    random_category new_cat
# 0                3   Large
# 1                2  Medium
# 2                1   Small
# 3                1   Small
# 4                3   Large

# %%
df['new_cat'] = df.random_category.apply(category_mapping)
df[['random_category', 'new_cat']].head()
# Out:
#    random_category new_cat
# 0                3   Large
# 1                2  Medium
# 2                1   Small
# 3                1   Small
# 4                3   Large

# %% [markdown]
# ## Порівняння колонок

# %%
df['new_cat']
# Out:
# 0          Large
# 1         Medium
# 2          Small
# 3          Small
# 4          Large
#            ...
# 381104    Medium
# 381105    Medium
# 381106    Medium
# 381107    Medium
# 381108     Large
# Name: new_cat, Length: 381109, dtype: object

# %%
df['new_cat'] == 'Small'
# Out:
# 0         False
# 1         False
# 2          True
# 3          True
# 4         False
#           ...
# 381104    False
# 381105    False
# 381106    False
# 381107    False
# 381108    False
# Name: new_cat, Length: 381109, dtype: bool

# %%
df['new_cat'] != 'Small'
# Out:
# 0          True
# 1          True
# 2         False
# 3         False
# 4          True
#           ...
# 381104     True
# 381105     True
# 381106     True
# 381107     True
# 381108     True
# Name: new_cat, Length: 381109, dtype: bool

# %%
df['new_cat'] <= 'Small'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 381104    True
# 381105    True
# 381106    True
# 381107    True
# 381108    True
# Name: new_cat, Length: 381109, dtype: bool

# %%
df['new_cat_dublicate'] = df['new_cat']

# %%
# порівняння колонок між собою
df['new_cat_dublicate'] == df['new_cat']
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 381104    True
# 381105    True
# 381106    True
# 381107    True
# 381108    True
# Length: 381109, dtype: bool

# %%
np.isclose(0.1 + 0.2, 0.3) #Функція перевіряє, чи числа достатньо близькі, а не ідеально рівні (з урахуванням похибки)
# Out:
# np.True_

# %% [markdown]
# ## Перетворення типу колонки

# %%
df.random_category.head()
# Out:
# 0    3
# 1    2
# 2    1
# 3    1
# 4    3
# Name: random_category, dtype: int64

# %%
df['random_category_str'] = df.random_category.astype(str)  # з колонки random_category хочемо зробити str

# %%
df[['random_category', 'random_category_str']].dtypes  # повертає типи даних (dtype) для двох колонок у DataFrame df
# Out:
# random_category         int64
# random_category_str    object
# dtype: object

# %%
type(df.random_category_str.loc[0])  # повертає тип конкретного значення (елемента) з колонки random_category_str у рядку з індексом 0
# Out:
# str

# %%
df['new_cat']
# Out:
# 0          Large
# 1         Medium
# 2          Small
# 3          Small
# 4          Large
#            ...
# 381104    Medium
# 381105    Medium
# 381106    Medium
# 381107    Medium
# 381108     Large
# Name: new_cat, Length: 381109, dtype: object

# %%
 # створює нову колонку new_cat_cat, де дані з new_cat перетворені у категоріальний тип (category)
df['new_cat_cat'] = df.new_cat.astype('category')

# %%
df['new_cat_cat']
# Out:
# 0          Large
# 1         Medium
# 2          Small
# 3          Small
# 4          Large
#            ...
# 381104    Medium
# 381105    Medium
# 381106    Medium
# 381107    Medium
# 381108     Large
# Name: new_cat_cat, Length: 381109, dtype: category
# Categories (3, object): ['Large', 'Medium', 'Small']

# %%
df[['new_cat_cat', 'new_cat']].memory_usage()   # показує, скільки пам’яті займають ці дві колонки (у байтах)
# Out:
# Index              132
# new_cat_cat     381241
# new_cat        3048872
# dtype: int64

# %% [markdown]
# ## Агрераційні операції над колонками

# %%
df.Age.mean(), df.Age.std()
# Out:
# (np.float64(38.822583565331705), 15.511611018090681)

# %%
df[['Age', 'Response']].mean()
# Out:
# Age         38.822584
# Response     0.122563
# dtype: float64

# %%
df[['Age', 'Response']].mode()
# Out:
#    Age  Response
# 0   24         0

# %%
df[['Age', 'Response']].agg(['mean', 'min', 'max']).round(3) # обчислює середнє, мін, макс для колонок Age і Response
# Out:
#          Age  Response
# mean  38.823     0.123
# min   20.000     0.000
# max   85.000     1.000

# %%
df.drop(columns=['random_category'])
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            1    Male   44                1         28.0                   0
# 1            2    Male   76                1          3.0                   0
# 2            3    Male   47                1         28.0                   0
# 3            4    Male   21                1         11.0                   1
# 4            5  Female   29                1         41.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 381104  381105    Male   74                1         26.0                   1
# 381105  381106    Male   30                1         37.0                   1
# 381106  381107    Male   21                1         30.0                   1
# 381107  381108  Female   68                1         14.0                   0
# 381108  381109    Male   46                1         29.0                   0
#
# ...

# %%
new_df = df.drop(columns=['random_category']) #щоб точно видалило колонку, то потрібно записати в нову змінну

# %%
new_df.columns, df.columns
# Out:
# (Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#         'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#         'Policy_Sales_Channel', 'Vintage', 'Response', 'New_col', 'new_cat',
#         'new_cat_dublicate', 'random_category_str', 'new_cat_cat'],
#        dtype='object'),
#  Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#         'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#         'Policy_Sales_Channel', 'Vintage', 'Response', 'New_col',
#         'random_category', 'new_cat', 'new_cat_dublicate',
#         'random_category_str', 'new_cat_cat'],
#        dtype='object'))

# %%
 # інший спосіб видалення колонки random_category з датафрейма df
df.drop(columns= ['random_category'], inplance=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 2
#       1 # видаляє колонку random_category з датафрейма df
# ----> 2 df.drop(columns= ['random_category'], inplance=True)
#
# TypeError: DataFrame.drop() got an unexpected keyword argument 'inplance'. Did you mean 'inplace'?

# %%
df.drop('Annual_Premium').head()   # не спрацює, бо drop() за замовчуванням видаляє рядки (index), а не колонки
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df.drop('Annual_Premium').head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df.drop(0).head() # видалило рядок з індексом 0
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
# 5   6  Female   24                1         33.0                   0
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
# 5    < 1 Year            Yes          2630.0                 160.0      176
#
#    Response  New_col  random_category new_cat new_cat_dublicate  \
# ...

# %%
df.drop([0, 1, 4]).head()  # видалило рядки з індексом 0, 1, 4
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 5   6  Female   24                1         33.0                   0
# 6   7    Male   23                1         11.0                   0
# 7   8  Female   56                1         28.0                   0
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 5    < 1 Year            Yes          2630.0                 160.0      176
# 6    < 1 Year            Yes         23367.0                 152.0      249
# 7    1-2 Year            Yes         32031.0                  26.0       72
#
#    Response  New_col  random_category new_cat new_cat_dublicate  \
# ...

# %%
df.drop('Annual_Premium', axis=1).head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Policy_Sales_Channel  Vintage  Response  \
# 0   > 2 Years            Yes                  26.0      217         1
# 1    1-2 Year             No                  26.0      183         0
# 2   > 2 Years            Yes                  26.0       27         1
# 3    < 1 Year             No                 152.0      203         0
# 4    < 1 Year             No                 152.0       39         0
#
#    New_col  random_category new_cat new_cat_dublicate random_category_str  \
# ...

# %%
def multicol_calculation(row):
    return row['Age']- row['Vintage']/365

# %%
df['complex_cal_col']= df.apply(multicol_calculation, axis =1)

# %%
df['complex_cal_col']
# Out:
# 0         43.405479
# 1         75.498630
# 2         46.926027
# 3         20.443836
# 4         28.893151
#             ...
# 381104    73.758904
# 381105    29.641096
# 381106    20.558904
# 381107    67.797260
# 381108    45.350685
# Name: complex_cal_col, Length: 381109, dtype: float64

# %% [markdown]
# ## Запис дата фрейма в файл

# %%
df.to_csv('res_lecture_3.csv')
